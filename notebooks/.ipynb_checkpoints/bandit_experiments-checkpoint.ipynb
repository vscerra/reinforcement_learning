# %% [markdown]
# # Multi-Armed Bandit Experiments
#
# Section 1 runs through simulations of stationary bandit algorithms:
#  - Greedy
#  - Epsilon-Greedy
#  - Upper Confidence Bound (UCB)
#  - Gradient Update
#
#    and includes plots of performance (in average rewards) and optimal action percentage over time
#
#
# Section 2 conducts a parameter study for:
#  - $\epsilon$ in Epsilon-Greedy
#  - C in UCB
#  - $\alpha$ in gradient update

# %% [markdown]
# ## Section 1: Comparison of performance of stationary bandit algorithms

# %%
import sys
import os

# Get the absolute path of the project directory
project_root = os.path.abspath('..')  # Go up one level to the project root
if project_root not in sys.path:
    sys.path.append(project_root)

# Verify that reinforcement_learning is in sys.path
#print(sys.path)

# %%
import numpy as np
import matplotlib.pyplot as plt

from k_bandits.bandit import Bandit
from k_bandits.algorithms import Greedy, EpsilonGreedy, UCB, GradientBandit
from k_bandits.experiment import run_experiment
from k_bandits.plots import plot_results

# %% [markdown]
# ### Define experiment parameters

# %%
k = 10 # number of arms
bandit_env = Bandit(k)

# define agent parameters
steps = 1000
runs = 2000

# define agents
agents = {
    "Greedy": (Greedy, {}),
    "Epsilon-Greedy (0.1)": (EpsilonGreedy, {"epsilon": 0.1}),
    "UCB (c=2)": (UCB, {"c": 2}),
    "Gradient (alpha=0.1)": (GradientBandit, {"alpha": 0.1})
}

# %% [markdown]
# ### Run Experiments

# %%
# run experiments
results = {}
optimal_actions = {}

for name, (algo_class, params) in agents.items():
    avg_rewards, optimal_action = run_experiment(algo_class, params, k, steps, runs)
    results[name] = avg_rewards
    optimal_actions[name] = optimal_action

# %% [markdown]
# ### Plot Algorithm Performance (Average Reward Over Time)

# %%
plot_results(results, title = "Gradient Update gives the best performance, but takes longer to reach optimality", ylabel = "average reward")

# %% [markdown]
# ### Plot Optimal Action Percentage Over Time

# %%
plot_results(optimal_actions, title = "UCB optimizes performance early, but Gradient makes slightly better selections eventually", ylabel = "optimal action %")

# %% [markdown]
# ## Section 2: Parameter Study

# %% [markdown]
# Each of the above algorithms has key parameters that influence their performance:
#
# | Algorithm        | Key Parameter  | Meaning |
# |-----------------|---------------|---------|
# | **Epsilon-Greedy** | \( $\epsilon$ \) | Controls how often exploration happens |
# | **UCB** | \( c \) | Determines the weight of exploration vs. exploitation |
# | **Gradient Bandit** | \( $\alpha$ \) | Learning rate that controls preference updates |
#
# In the following section, we'll see how these parameters affect the **average reward** and **optimal action selection** over time.

# %% [markdown]
# ### Parameter Study: Epsilon-Greedy with varying values of $\epsilon$

# %%
epsilons = [0.01, 0.1, 0.3, 0.5]
eps_results = {}
eps_optimal = {}

for eps in epsilons:
    avg_rewards, optimal_action = run_experiment(EpsilonGreedy, {"epsilon":eps}, k, steps, runs)
    eps_results[f"epsilon = {eps}"] = avg_rewards
    eps_optimal[f"epsilon = {eps}"] = optimal_action

plot_results(eps_results, title="Effect of epsilon on Epsilon-Greedy", ylabel = "average reward")
plot_results(eps_optimal, title= "Effect of epsilon on optimal actions in Epsilon-Greedy", ylabel = "optimal action %")
